# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
#from xgboost import XGBClassifier

# %%
data = pd.read_csv("Stress.csv")

# %%
data.head()
# Out:
#           subreddit post_id sentence_range  \
# 0              ptsd  8601tu       (15, 20)
# 1        assistance  8lbrx9         (0, 5)
# 2              ptsd  9ch1zh       (15, 20)
# 3     relationships  7rorpp        [5, 10]
# 4  survivorsofabuse  9p2gbc         [0, 5]
#
#                                                 text  label  confidence  \
# 0  He said he had not felt that way before, sugge...      1         0.8
# 1  Hey there r/assistance, Not sure if this is th...      0         1.0
# 2  My mom then hit me with the newspaper and it s...      1         0.8
# 3  until i met my new boyfriend, he is amazing, h...      1         0.6
# 4  October is Domestic Violence Awareness Month a...      1         0.8
#
#    social_timestamp
# 0        1521614353
# 1        1527009817
# 2        1535935605
# 3        1516429555
# 4        1539809005

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2838 entries, 0 to 2837
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   subreddit         2838 non-null   object
#  1   post_id           2838 non-null   object
#  2   sentence_range    2838 non-null   object
#  3   text              2838 non-null   object
#  4   label             2838 non-null   int64
#  5   confidence        2838 non-null   float64
#  6   social_timestamp  2838 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 155.3+ KB

# %%
data.isnull().sum()
# Out:
# subreddit           0
# post_id             0
# sentence_range      0
# text                0
# label               0
# confidence          0
# social_timestamp    0
# dtype: int64

# %%
#Realizaremos una wordcloud para analizar la frecuencia de las palabras

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
stopword=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /home/ian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean(text):
    """
    Normalize text column
    """
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# %%
data["text"] = data["text"].apply(clean)

# %%
text = " ".join(i for i in data.text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, 
                      background_color="black").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
data["new_label"] = data["label"].map({0: "No Stress", 1: "Stress"})
data = data[["text", "new_label"]]
print(data.head())
# Out:
#                                                 text  new_label
# 0  said felt way sugget go rest trigger ahead you...     Stress
# 1  hey rassist sure right place post goe  im curr...  No Stress
# 2  mom hit newspap shock would know dont like pla...     Stress
# 3  met new boyfriend amaz kind sweet good student...     Stress
# 4  octob domest violenc awar month domest violenc...     Stress

# %%
print(data.shape)
"""
Para esta primer versión utilizaremos el fragmento de texto y su relación
binaria de estrés o no estrés
FYI: Espero tener el suficiente tiempo para implementar una version que recoja mas datos
y realizar una comparativa entre ambas

---
Cambio
---
Es posible que sea necesario utilizar más datos para mejorar el aprendizaje
"""
datax=data.drop(columns=)#Columna con datos de entrada(texto)
datay=data[data.columns[1]] #Columna con datos de salida
#print(datax)
#print(datay)
# Out:
# (2838, 2)

# %% [markdown]
# # One Hot Encoding
# Convertimos en OneHot encoding la columna del texto

# %%
datax=pd.get_dummies(datax)
datax.head()
# Out:
#    \tit summer start new job bartend  met girl equal odd lot similar interest look thing  quick becam enamor didnt take long us move togeth  start find project around hous fix would surpris home cook meal note gush relationship  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    \tyou must iphon ipod touch  generat order particip earn  complet studi \tif elig ask download io app call rep also complet sever onlin survey prior direct follow use app inform pleas email us  studi administ ucsf thrive lab base ucsf princip investig dr aoif odonovan contact aoif question  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#                                                     resent relationship son  son daddi boy even type hear wait say daddi daddi daddi come give hug come home bare notic wife gone come home  ‎this also someth shes recent admit feel guilti feel like put effort beyond need  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#         grew short stubbi orang hair freckl face awkward boy seem strong tattoo pierc tall ginger man thought alway want       time  thought love didnt know told often phone letter girl thought could never get leagu word  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#         tldr fianc complet cut son sulk day sport team lose tire plan live around team cancel plan lose doesnt see problem dont know feel like cant keep  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#         tldr met guy month ago weve hung time im littl wari age gap dont much experi accur read signal mild physic affection lean toward hit arm play pull thing hair give compliment seem genuin sincer arent quit non platon thinkwhat look  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#        arent promot one compani anoth thought opportun cant reach therapist irl consid method ask question hope find help inform uitherapi answer want good luck  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#        tldr met friend friend parti past coupl day hes msging girlfriend random shit isnt actual creepi longer want talk ignor messag keep messag anyway want stop minim dramaconfront im sure possibl  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#       decid spent long let anxieti win dont want inform anxieti anymor want expert understand everi aspect  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#       emot physic abus mother grow absent drunk father  convinc  year old man girlfriend introduc drug  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    your stuck anxious move know alway make progress okay way im grate sub realli amaz see wasnt alon read other struggl accomplish inspir beyond belief hope your read find inspir  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    your super grate your aliv want share everyon dont feel like one lucki one probabl someth stuf know sister survivor  victim think miss count walk wound today  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    youv kind incred generous mom look suggest recommend provid extrem grate everyth youv done us wonder know care consider give peopl will help peopl like us youv warm heart selfless thank much  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    · parentpar provid healthi meal enough daili exercis activ · didn't chang habit becam age · cook · busi · made daili planner day abl notic opportun abl prep meal cook  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    “either girlfriend life” fwb told refus girlfriend cours we'r stranger it break heart want life bad friend wonder connect that hard come least hate lose  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    “hey can't lay like man” could tell want say overs krillin look mother… inhal tire sat kill time shelter morn began open decid make base atlanta knew leav north would make hard return savannah ticket bound georgia court day  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    “nice thought” even though told mother never leav drink bar didn't cross mind might someth put drink push intox start sip drink felt alcohol hit felt drunk said i'v order uber us thought drop back home don't actual rememb ride home uber pull apart complex said come insid know you'r hungri pizza thought eat pizza would good idea alcohol follow insid  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    “the best time plant tree  year ago second best time today” new favorit quot know anxieti crippl us accomplish one simpl task we'v put it one stop closer recoveri today got haircut made excus month kept cancel appoint  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    “yeah saw think steal” “that think keep eye man place ain't bad gotta watch yourself” nod fell asleep woke stolen charger  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ● activ staff member ● activ support staff ● help channel channel share art talk other voic chat ● rule keep communiti safe ● ad creativ corner place writer artist kind share work get feedback theyd like
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 2818 columns]

# %% [markdown]
# # Escalado de datos
# Ahora escalaremos los datos para que queden dentro de un rango mas corto

# %%
escalador = StandardScaler()
datax = escalador.fit_transform(datax)
print(datax)
# Out:
# [[-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]
#  [-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]
#  [-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]
#  ...
#  [-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]
#  [-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]
#  [-0.01877458 -0.01877458 -0.01877458 ... -0.01877458 -0.01877458
#   -0.01877458]]
